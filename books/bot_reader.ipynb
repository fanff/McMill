# %%
import pandas as pd

import sqlalchemy

from sqlalchemy.engine import create_engine

# %%
#!pip install mysqlclient

# %%
# create sql connection engine to the local logserver
eng = create_engine("mysql://username:pass@192.168.168.3/minecraft")


# dumping every tables into pandas frames
wad = {}
with eng.connect() as conn:
    alltables = pd.read_sql("SHOW TABLES;",conn)
    
    for tab in alltables.values:
        print("loading ",tab[0])
        df = pd.read_sql("SELECT * FROM `%s`;"%tab[0],conn)
        
        wad[tab[0]] = df
        
alltables
# Out:
# loading  lb-players
# loading  lb-world
# loading  lb-world-chest
# loading  lb-world-kills
# loading  lb-world-sign
# loading  lb-world_nether
# loading  lb-world_nether-chest
# loading  lb-world_nether-sign
# loading  lb-world_the_end
# loading  lb-world_the_end-chest
# loading  lb-world_the_end-sign
#        Tables_in_minecraft
# 0               lb-players
# 1                 lb-world
# 2           lb-world-chest
# 3           lb-world-kills
# 4            lb-world-sign
# 5          lb-world_nether
# 6    lb-world_nether-chest
# 7     lb-world_nether-sign
# 8         lb-world_the_end
# 9   lb-world_the_end-chest
# 10   lb-world_the_end-sign

# %%
# load players info
playsCols = ["playerid", "playername","firstlogin","lastlogin","onlinetime","ip"]
pdf = wad["lb-players"][playsCols]
pdf
# Out:
#    playerid    playername          firstlogin           lastlogin  onlinetime  \
# 0         1  dummy_record                 NaT                 NaT           0
# 1         2       testbot 2020-02-09 20:45:04 2020-02-09 20:45:04           0
# 2         3          fanf 2020-02-09 20:45:58 2020-02-09 20:50:36         123
# 3         4      LavaFlow                 NaT                 NaT           0
# 4         5      Enderman                 NaT                 NaT           0
#
#                      ip
# 0
# 1     /172.24.0.1:50902
# 2  /192.168.168.1:51095
# 3
# 4

# %%
# join "world" event with players
lbw = wad["lb-world"]
lbw = lbw.set_index("playerid").join(pdf.set_index("playerid"))

# %%
# "fanf" player actions
lbw[lbw["playername"]=="fanf"]
# Out:
#           id                date  replaced  type  data   x   y    z  \
# playerid
# 3         31 2020-02-09 20:46:35        31     0     1 -58  67  239
# 3         32 2020-02-09 20:46:46        31     0     1 -66  66  246
# 3         34 2020-02-09 20:50:44       175     0     1 -80  67  236
# 3         35 2020-02-09 20:50:44       175     0    10 -80  68  236
# 3         36 2020-02-09 20:50:44       175     0    10 -80  68  235
# 3         37 2020-02-09 20:50:44       175     0     1 -80  67  235
# 3         38 2020-02-09 20:50:47       175     0     1 -81  67  231
# 3         39 2020-02-09 20:50:47       175     0    10 -81  68  231
# 3         40 2020-02-09 20:50:49       175     0     1 -84  66  235
# 3         41 2020-02-09 20:50:49       175     0    10 -84  67  235
# 3         42 2020-02-09 20:50:49       175     0     1 -84  66  236
# 3         43 2020-02-09 20:50:49       175     0    10 -84  67  236
# 3         44 2020-02-09 20:50:49       175     0    10 -83  67  238
# ...
